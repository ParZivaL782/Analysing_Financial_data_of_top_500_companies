# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df=pd.read_csv("Financial Analytics data.csv")

# %%
df
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 0        1   Reliance Inds.    583436.720000       99810.000000
# 1        2              TCS    563709.840000       30904.000000
# 2        3        HDFC Bank    482953.590000       20581.270000
# 3        4              ITC    320985.270000        9772.020000
# 4        5          H D F C    289497.370000       16840.510000
# ..     ...              ...              ...                ...
# 483    496  Lak. Vilas Bank      3029.570000         790.170000
# 484    497            NOCIL      3026.260000         249.270000
# 485    498    Orient Cement      3024.320000         511.530000
# 486    499  Natl.Fertilizer      3017.070000        2840.750000
# 487    500        L T Foods     28043.857119        4395.976849
#
# [488 rows x 4 columns]

# %%
# @title Sales Qtr - Crore

from matplotlib import pyplot as plt

# %%
df.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       488.000000         488.000000
# mean   251.508197     28043.857119        4395.976849
# std    145.884078     58912.585788        9589.680655
# min      1.000000      3017.070000          47.240000
# 25%    122.750000      4879.612500         725.732500
# 50%    252.500000     10380.425000        2095.335000
# 75%    378.250000     25502.085000        4395.976849
# max    500.000000    583436.720000      110666.930000

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-7-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.drop(df.columns[4],axis=1,inplace=True)

# %%
plt.scatter(df["Mar Cap - Crore"], df["Sales Qtr - Crore"])
plt.xlabel("Market Capitalization (crores)")
plt.ylabel("Quarterly Sales (crores)")
plt.title("Scatter Plot of Market Cap vs Quarterly Sales")
plt.show()

# %%
df['Mar Cap - Crore'].plot(kind='line', figsize=(8,4), title='Mar Cap - Crore')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['Sales Qtr - Crore'].plot(kind='line', figsize=(8, 4), title='Sales Qtr - Crore')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
correlation = df["Mar Cap - Crore"].corr(df["Sales Qtr - Crore"])
print(f"Correlation between Market Cap and Quarterly Sales: {correlation:.2f}")
# Out:
# Correlation between Market Cap and Quarterly Sales: 0.61

# %%
correlation = np.reshape(correlation, (1, 1))
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.show()
